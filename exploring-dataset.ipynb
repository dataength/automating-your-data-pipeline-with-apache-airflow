# %%
import pandas as pd

# %%
products = pd.read_csv('dataset/product-lookup-table.csv', header=1)

# %%
stores = pd.read_csv('dataset/store-lookup-table.csv', header=1)

# %%
transactions = pd.read_csv('dataset/transaction-data-table.csv', header=1)

# %%
products.head(10)
# Out:
#           UPC               DESCRIPTION   MANUFACTURER               CATEGORY  \
# 0  1111009477    PL MINI TWIST PRETZELS  PRIVATE LABEL             BAG SNACKS
# 1  1111009497         PL PRETZEL STICKS  PRIVATE LABEL             BAG SNACKS
# 2  1111009507         PL TWIST PRETZELS  PRIVATE LABEL             BAG SNACKS
# 3  1111035398  PL BL MINT ANTSPTC RINSE  PRIVATE LABEL  ORAL HYGIENE PRODUCTS
# 4  1111038078  PL BL MINT ANTSPTC RINSE  PRIVATE LABEL  ORAL HYGIENE PRODUCTS
# 5  1111038080  PL ANTSPTC SPG MNT MTHWS  PRIVATE LABEL  ORAL HYGIENE PRODUCTS
# 6  1111085319  PL HONEY NUT TOASTD OATS  PRIVATE LABEL            COLD CEREAL
# 7  1111085345            PL RAISIN BRAN  PRIVATE LABEL            COLD CEREAL
# 8  1111085350   PL BT SZ FRSTD SHRD WHT  PRIVATE LABEL            COLD CEREAL
# 9  1111087395   PL SR CRUST SUPRM PIZZA  PRIVATE LABEL           FROZEN PIZZA
#
#                SUB_CATEGORY PRODUCT_SIZE  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# ...

# %%
products[
    ['UPC', 'DESCRIPTION', 'MANUFACTURER', 'CATEGORY', 'SUB_CATEGORY', 'PRODUCT_SIZE']
].to_csv('mnt/airflow/dags/products-lookup-table-cleaned.csv', index=False, header=False)

# %%
products.UPC.unique()
# Out:
# array([ 1111009477,  1111009497,  1111009507,  1111035398,  1111038078,
#         1111038080,  1111085319,  1111085345,  1111085350,  1111087395,
#         1111087396,  1111087398,  1600027527,  1600027528,  1600027564,
#         2066200530,  2066200531,  2066200532,  2840002333,  2840004768,
#         2840004770,  3000006340,  3000006560,  3000006610,  3120505000,
#         3120505100,  3120506000,  3500068914,  3700019521,  3700031613,
#         3700044982,  3800031829,  3800031838,  3800039118,  4116709428,
#         4116709448,  4116709565,  7027312504,  7027316204,  7027316404,
#         7110410455,  7110410470,  7110410471,  7192100336,  7192100337,
#         7192100339,  7218063052,  7218063979,  7218063983,  7797502248,
#         7797508004,  7797508006, 31254742725, 31254742735, 31254742835,
#        88491201426, 88491201427, 88491212971])

# %%
products.PRODUCT_SIZE.unique()
# Out:
# array(['15 OZ', '1.5 LT', '500 ML', '12.25 OZ', '20 OZ', '18 OZ',
#        '32.7 OZ', '30.5 OZ', '29.6 OZ', '12 OZ', '13.2 OZ', '13.3 OZ',
#        '14.7 OZ', '10 OZ', '16 OZ', '13 OZ', '14 OZ', '30 OZ', '31 OZ',
#        '27 OZ', '16 CT', '4.2 OZ', '1 LT', '12.2 OZ', '532 ML', '29.8 OZ',
#        '28.3 OZ', '22.7 OZ', '27.35 OZ', '26.11 OZ', '11 OZ'],
#       dtype=object)

# %%
stores.head(10)
# Out:
#    STORE_ID           STORE_NAME ADDRESS_CITY_NAME ADDRESS_STATE_PROV_CODE  \
# 0       389           SILVERLAKE          ERLANGER                      KY
# 1      2277   ANDERSON TOWNE CTR        CINCINNATI                      OH
# 2      4259        WARSAW AVENUE        CINCINNATI                      OH
# 3      6379             KINGWOOD          KINGWOOD                      TX
# 4      6431         AT WARD ROAD           BAYTOWN                      TX
# 5     13853           RICHARDSON        RICHARDSON                      TX
# 6     13859             MCKINNEY          MCKINNEY                      TX
# 7     15755  KROGER JUNCTION S/C          PASADENA                      TX
# 8     23327              HOUSTON           HOUSTON                      TX
# 9     23345               FRISCO            FRISCO                      TX
#
#    MSA_CODE SEG_VALUE_NAME  PARKING_SPACE_QTY  SALES_AREA_SIZE_NUM  \
# 0     17140     MAINSTREAM              408.0                46073
# ...

# %%
stores[
    ['STORE_ID', 'STORE_NAME', 'ADDRESS_CITY_NAME', 'ADDRESS_STATE_PROV_CODE', 'MSA_CODE', 'SEG_VALUE_NAME', 'PARKING_SPACE_QTY', 'SALES_AREA_SIZE_NUM', 'AVG_WEEKLY_BASKETS']
].to_csv('mnt/airflow/dags/store-lookup-table-cleaned.csv', index=False, header=False)

# %%
stores.ADDRESS_STATE_PROV_CODE.unique()
# Out:
# array(['KY', 'OH', 'TX', 'IN'], dtype=object)

# %%
stores.STORE_ID.unique()
# Out:
# array([  389,  2277,  4259,  6379,  6431, 13853, 13859, 15755, 23327,
#        23345, 25001, 26983,   623,  2541,  4489, 10019, 13609, 15531,
#        17599, 19265, 21485, 26981,  4503,  2513, 19523, 19533, 25021,
#          367,  2505,  6187,  8035,  8041, 13837, 15765, 17615, 21479,
#        25027, 25253, 29159, 17627,   613,  2523, 11757, 12011, 21227,
#        21237, 23075, 23349, 25229, 25233, 26973,  4245, 11967, 11993,
#        21221, 23055, 24991, 25261,  2281,  2495,  4521,  8263,  9825,
#        15547,   387,  2279,  6179, 11761, 13827, 15541, 15763, 19521,
#        21213, 23061, 23067, 27175, 28909])

# %%
stores.SALES_AREA_SIZE_NUM.unique()
# Out:
# array([46073, 81958, 48813, 50237, 43698, 53586, 47824, 34373, 50722,
#        46369, 34177, 48782, 46930, 29231, 49030, 35675, 55663, 33667,
#        36994, 55685, 42081, 56230, 61833, 48594, 48330, 62961, 24721,
#        41644, 55474, 10788, 49074, 49164, 49068, 48632, 49104, 62656,
#        33931, 54927, 59213, 64926, 32943, 41325, 85710, 86517, 51105,
#        46212, 59241, 48128, 58563, 25072, 57741, 22920, 77730, 46368,
#        68500, 48462, 34628, 51055, 54124, 48132, 44547, 44175, 54448,
#        53905, 50766, 38858, 47530, 47757, 46630, 42437, 37319, 50224,
#        85876])

# %%
stores.AVG_WEEKLY_BASKETS.unique()
# Out:
# array([24767, 54053, 31177, 20620, 24322, 15787, 15345, 18291, 30258,
#        21947, 18035, 31461, 36741, 11019, 21345, 19068, 21232, 13344,
#        15134, 31578, 26472, 25122, 25289, 32423, 24568, 28243, 34191,
#        12707, 14460, 20015, 10435, 14849, 27262, 25351, 32491, 29436,
#        43893, 11934, 25917, 18197, 29386, 14201, 16904, 23153, 34875,
#        38465, 18842, 27823, 34977, 35788, 28241, 19275, 15916, 26101,
#        17010, 13000, 50619, 26189, 32297, 25507, 25633, 18877, 29916,
#        27358, 22867, 23037, 35288, 23348, 26001, 18665, 12176, 14052,
#        14512, 16591, 14556, 24902, 28986])

# %%
transactions.head(10)
# Out:
#   WEEK_END_DATE  STORE_NUM         UPC  UNITS  VISITS  HHS   SPEND  PRICE  \
# 0     14-Jan-09        367  1111009477     13      13   13   18.07   1.39
# 1     14-Jan-09        367  1111009497     20      18   18   27.80   1.39
# 2     14-Jan-09        367  1111009507     14      14   14   19.32   1.38
# 3     14-Jan-09        367  1111035398      4       3    3   14.00   3.50
# 4     14-Jan-09        367  1111038078      3       3    3    7.50   2.50
# 5     14-Jan-09        367  1111038080      2       2    2    5.18   2.59
# 6     14-Jan-09        367  1111085319     14      13   13   26.32   1.88
# 7     14-Jan-09        367  1111085345     29      26   25   54.52   1.88
# 8     14-Jan-09        367  1111085350     35      27   25   69.30   1.98
# 9     14-Jan-09        367  1111087395     50      40   40  168.00   3.36
#
#    BASE_PRICE  FEATURE  DISPLAY  TPR_ONLY  Unnamed: 12  Unnamed: 13  \
# 0        1.57        0        0         1          NaN          NaN
# ...

# %%
transactions[
    ['WEEK_END_DATE', 'STORE_NUM', 'UPC', 'UNITS', 'VISITS', 'HHS', 'SPEND', 'PRICE', 'BASE_PRICE', 'FEATURE', 'DISPLAY', 'TPR_ONLY']
].to_csv('mnt/airflow/dags/transactions-cleaned.csv', index=False, header=False)

# %%
transactions.WEEK_END_DATE.unique()
# Out:
# array(['14-Jan-09', '21-Jan-09', '28-Jan-09', '4-Feb-09', '11-Feb-09',
#        '18-Feb-09', '25-Feb-09', '4-Mar-09', '11-Mar-09', '18-Mar-09',
#        '25-Mar-09', '1-Apr-09', '8-Apr-09', '15-Apr-09', '22-Apr-09',
#        '29-Apr-09', '6-May-09', '13-May-09', '20-May-09', '27-May-09',
#        '3-Jun-09', '10-Jun-09', '17-Jun-09', '24-Jun-09', '1-Jul-09',
#        '8-Jul-09', '15-Jul-09', '22-Jul-09', '29-Jul-09', '5-Aug-09',
#        '12-Aug-09', '19-Aug-09', '26-Aug-09', '2-Sep-09', '9-Sep-09',
#        '16-Sep-09', '23-Sep-09', '30-Sep-09', '7-Oct-09', '14-Oct-09',
#        '21-Oct-09', '28-Oct-09', '4-Nov-09', '11-Nov-09', '18-Nov-09',
#        '25-Nov-09', '2-Dec-09', '9-Dec-09', '16-Dec-09', '23-Dec-09',
#        '30-Dec-09', '6-Jan-10', '13-Jan-10', '20-Jan-10', '27-Jan-10',
#        '3-Feb-10', '10-Feb-10', '17-Feb-10', '24-Feb-10', '3-Mar-10',
#        '10-Mar-10', '17-Mar-10', '24-Mar-10', '31-Mar-10', '7-Apr-10',
# ...

# %%
pd.to_datetime(transactions.WEEK_END_DATE, format='%d-%b-%y')
# Out:
# 0        2009-01-14
# 1        2009-01-14
# 2        2009-01-14
# 3        2009-01-14
# 4        2009-01-14
#             ...
# 524945   2012-01-04
# 524946   2012-01-04
# 524947   2012-01-04
# 524948   2012-01-04
# 524949   2012-01-04
# Name: WEEK_END_DATE, Length: 524950, dtype: datetime64[ns]

# %%
transactions.HHS.unique()
# Out:
# array([  13,   18,   14,    3,    2,   25,   40,   42,   49,   10,   19,
#           6,   17,   72,   41,   34,   56,    1,    8,    9,   22,   15,
#          94,   89,   27,    4,    5,   30,   35,   71,   16,   65,   53,
#           7,   36,   50,   29,   28,   11,   68,   66,   54,   96,   24,
#          51,  121,   47,   59,   58,   23,   52,   38,   33,   20,   76,
#          44,   26,   12,   46,   21,  135,  157,   63,  125,  112,   73,
#         212,   39,   91,   87,   60,   45,   31,   81,   62,   43,   80,
#         175,   67,   48,   37,   32,  115,  103,   57,   95,   84,   55,
#         106,  101,   78,  145,   69,   79,   75,   85,  143,   97,   61,
#         120,  102,  173,  194,  108,  104,   82,   64,   88,  109,  167,
#          70,  149,  159,  140,  136,  114,   74,   77,   86,  128,  122,
#         113,   83,  118,   92,   90,  169,  123,   99,  105,  110,   93,
#         100,  168,  171,  124,  154,  116,  163,  137,  111,  127,  158,
# ...

# %%
transactions.FEATURE.unique()
# Out:
# array([0, 1])
